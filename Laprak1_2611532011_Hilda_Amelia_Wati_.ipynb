# %% [markdown]
# <a href="https://colab.research.google.com/github/hildaamelia0376-sys/2026_Alpro_C_2611532011/blob/main/Laprak1_2611532011_Hilda_Amelia_Wati_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **PRAKTIKUM ALGORITMA DAN PEMOGRAMAN**
#
# **“PENGENALAN PYTHON,VS CODE DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Hilda Amelia Wati**
#
# **2611532011**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 1 (Pengenalan Python, VS Code dan koneksi ke GitHub) yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pengenalan aplikasi Python, VS Code dan juga koneksi ke GitHub
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Proses pembuatan kode program menggunakan python di VS Code dan mengelola repositori proyek melalui GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Algoritma dan pemrograman merupakan dasar penting dalam bidang informatika yang membantu mahasiswa memahami cara menyelesaikan masalah secara logis dan sistematis. Salah satu bahasa pemrograman yang digunakan dalam praktikum adalah Python karena memiliki sintaks yang sederhana dan mudah dipahami oleh pemula. Melalui pengenalan Python, mahasiswa dapat mempelajari dasar-dasar pemrograman serta menerapkannya dalam pembuatan program sederhana.
#
# Untuk mendukung proses pemrograman tersebut, digunakan Visual Studio Code (VS Code) sebagai aplikasi untuk menulis dan menjalankan kode Python. Selain itu, GitHub diperkenalkan sebagai media untuk menyimpan, mengelola, dan berbagi kode program. Dengan mengenal Python, VS Code, dan GitHub secara bersamaan, mahasiswa diharapkan dapat memahami proses dasar pengembangan program serta memiliki keterampilan yang dapat digunakan dalam praktikum maupun pengembangan proyek selanjutnya.
#
#
# ## 1.2 Tujuan
# 1. Mengenal dasar-dasar bahasa pemrograman Python.
# 2. Memahami penggunaan VS Code untuk menulis dan menjalankan program.
# 3. Mengenal fungsi dan penggunaan dasar GitHub dalam menyimpan kode program
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat memahami konsep dasar pemrograman Python.
# 2. Mahasiswa mampu menggunakan VS Code sebagai lingkungan pengembangan program.
# 3. Mahasiswa mampu menyimpan dan mengelola kode menggunakan GitHub.

# %% [markdown]
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Python
#    adalah bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python banyak digunakan untuk membuat aplikasi, mengolah data, kecerdasan buatan, dan berbagai kebutuhan pemrograman lainnya.
#
# 2. Visual Studio Code (VS Code)
#    adalah aplikasi code editor yang digunakan untuk menulis, mengedit, dan menjalankan kode program. VS Code mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan fitur seperti debugging dan berbagai ekstensi.
#
# 3. GitHub
#    adalah platform berbasis internet yang digunakan untuk menyimpan, mengelola, dan berbagi kode program. GitHub juga memungkinkan beberapa orang bekerja sama dalam satu proyek serta mencatat perubahan pada kode menggunakan sistem kontrol versi Git.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "C_2611532011"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print("Hello wordl")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a/n"
"Hilda Amelia Wati dan 2611532011")

# %% [markdown]
# **Penjelasan :**
#
# 1. Bagian pertama sampai keenam sebagai penjelas sebuah struktur program.
# 2. Bagian ketujuh sampai terakhir menghasilkan output.
# 3. Program ini dijalankan dengan bahasa python.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum Algoritma dan Pemrograman tentang pengenalan Python, VS Code, dan GitHub, dapat disimpulkan bahwa ketiga tools tersebut memiliki peran penting dalam proses pemrograman. Python digunakan untuk membuat program, VS Code digunakan untuk menulis dan menjalankan kode, sedangkan GitHub digunakan untuk menyimpan dan mengelola kode program.
#
# Melalui praktikum ini, mahasiswa dapat memahami dasar penggunaan Python, mengenal lingkungan pemrograman melalui VS Code, serta mengetahui cara menyimpan dan mengelola program menggunakan GitHub. Praktikum ini menjadi dasar untuk mengembangkan kemampuan pemrograman pada materi dan proyek selanjutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2024). Python 3 Documentation. Python Software Foundation.
#
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Microsoft.
#
#
# [3] Chacon, S., & Straub, B. (2014). Pro Git (2nd ed.). Apress.
